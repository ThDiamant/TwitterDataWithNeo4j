# %% [markdown]
#    # Introduction
#
# Twitter is one of the most popular social media platforms and a rich source of data for analyzing social trends and user behavior.
#
# With the help of Neo4j, a powerful graph database, we can easily represent Twitter data as a graph and perform complex queries to gain insights into the data.
#
# In this tutorial, we will go through the process of setting up Neo4j, importing Twitter data into Neo4j using Python, and performing some basic queries on the data.

# %% [markdown]
# Population of the Neo4j graph model with the tweets that have been collected in Python

# %% [markdown]
# ### Install Required Packages

# %% [markdown]
# Before we dive into the code, let's talk a little bit about Neo4j. Neo4j is a graph database that is optimized for storing and querying graph data. It is particularly useful for scenarios where relationships between data points are just as important as the data points themselves. For example, if you were building a social network, the relationships between users (e.g., friends, followers, etc.) would be just as important as the users themselves.
#
# To get started, we need to install a few packages that we will be using in our Python code. Specifically, we will be using the neo4j python library. These packages will allow us to interact with Neo4j and perform any queries we want. Furthermore we need an active (local) Neo4j Graph DB instance to be active.
#
# Here's the code block to install these packages:

# %%
# !pip install neo4j

# %% [markdown]
# Here, we are installing the following package:
#
# - neo4j: This is another Python package that provides a driver for interacting with Neo4j databases.
#
# Now that we have installed the required packages, we can move on to the next step.

# %% [markdown]
# ### Import libraries

# %% [markdown]
# Now we need to import the necessary packages for our Python script to interact with Neo4j. Specifically, we're importing:
#
# - json: a package for working with JSON data
# - numpy: a package for scientific computing with Python
# - pandas: a package for data manipulation and analysis
# - neo4j: a package for connecting to a Neo4j database
#
# We'll use these packages to load data from a JSON file, create nodes and relationships in Neo4j, and perform queries on the database.

# %%
import json

import numpy as np
import pandas as pd

from neo4j import GraphDatabase

# %% [markdown]
# ### Open JSON file with python

# %% [markdown]
# Let's open the JSON file, WDM1.json, using the json package and reads its contents into the data variable. The encoding parameter is set to 'utf-8' to ensure that the data is properly decoded from the file. We can assume that the JSON file contains data in a specific format that we will use to create nodes and relationships in Neo4j.

# %%
# tweets_json = 'C:\\Users\\Greg\\Documents\\vakali\\WDM1.json'
tweets_json = 'C:\\Users\\costa\\Documents\\MSc assignments\\Web Mining\\1st Lab Project - Neo4j\\wdm1_clean.json'

with open(tweets_json, encoding='utf-8') as data_file:
    data = json.load(data_file)

# %% [markdown]
# ### Clean Up of the data
#
# The below code is deleting the context_annotations key from the tweets in the data list.

# %%
for tweet in data:
    try:
        del tweet['includes']['tweets'][0]['context_annotations']
    except:
        continue
        # No context annotations in tweet 0
        
    try:
        del tweet['includes']['tweets'][1]['context_annotations']
    except:
        continue
        # No context annotations in tweet 1

# %% [markdown]
# The below code is creating a dictionary for each of the nodes and relationships that we will be using in our graph.
#
# Specifically it creates five Python dictionaries (`users_dict`, `tweets_dict`, `url_dict`, `hashtag_dict`, and `user_tweet_relationship`) that will be used to store information about Twitter users, their tweets, and relationships between them.
#
# The `users_dict` dictionary contains information about Twitter users, including their user ID, username, and number of followers. The `tweets_dict` dictionary contains information about tweets, including the tweet ID, text, impression count, date, and number of replies. The `url_dict` dictionary contains URLs that have been used in tweets, while the `hashtag_dict` dictionary contains hashtags that have been used in tweets.
#
# Finally, the `user_tweet_relationship` dictionary contains information about relationships between Twitter users and their tweets, while the `user_mentioned_relationship`, `user_used_hashtag`, `user_used_url`, `tweet_has_url`, and `tweet_has_hashtag` dictionaries contain information about other types of relationships between users, tweets, and various entities like hashtags and URLs.
#
# These dictionaries will be useful for storing information about the data extracted from the JSON file, and they will be used later to create nodes and relationships in the Neo4j database.

# %%
users_dict = {'user_id': [],
             'username': [],
             'followers_count': []}

tweets_dict = {'tweet_id': [],
              'text': [],
              'impression_count': [],
              'tweet_date': [],
              'reply_count': []}

url_dict = {'url': []}

hashtag_dict = {'hashtag': []}

user_tweet_relationship = {'user_id': [],
                            'tweet_id': [],
                          'type': [],
                          'date': []}

user_mentioned_relationship = {'user_id': [],
                               'mentioned_user_id': [],
                               'in': []}

user_used_hashtag = {'user_id': [],
                    'hashtag': [],
                    'in': []}

user_used_url = {'user_id': [],
                'url': [],
                'in': []}

tweet_has_url = {'tweet_id': [],
                'url': []}

tweet_has_hashtag = {'tweet_id': [],
                    'hashtag': []}

# %% [markdown]
# Updating the dictionaries with the data from the tweets.
#
# This is a Python function called `update_dictionary` which takes two arguments, `dictionary_to_be_updated` and `data`. The purpose of this function is to update a specific dictionary based on the given data.
#
# There are 10 different dictionaries that can be updated using this function, each one corresponding to a different type of data. Depending on which dictionary is being updated, the function will append the data to the appropriate keys in the dictionary.
#
# For example, if `dictionary_to_be_updated` is `'users_dict'`, the function will append the `user_id`, `username`, and `followers_count` values from the data argument to their respective keys in the `users_dict` dictionary.
#
# Overall, this function is a useful tool for organizing the data from the provided JSON file into separate dictionaries, each corresponding to a different type of information. This will make it easier to create nodes and relationships in the Neo4j database later on.

# %%
def update_dictionary(dictionary_to_be_updated, data):
    if dictionary_to_be_updated == 'users_dict':
        users_dict['user_id'].append(data[0])
        users_dict['username'].append(data[1])
        users_dict['followers_count'].append(data[2])
    
    elif dictionary_to_be_updated == 'tweets_dict':
        tweets_dict['tweet_id'].append(data[0])
        tweets_dict['text'].append(data[1])
        tweets_dict['impression_count'].append(data[2])
        tweets_dict['tweet_date'].append(data[3])
        tweets_dict['reply_count'].append(data[4])
    
    elif dictionary_to_be_updated == 'url_dict':
        url_dict['url'].append(data[0])
    
    elif dictionary_to_be_updated == 'hashtag_dict':
        hashtag_dict['hashtag'].append(data[0])
    
    elif dictionary_to_be_updated == 'user_tweet_relationship':
        user_tweet_relationship['user_id'].append(data[0])
        user_tweet_relationship['tweet_id'].append(data[1])
        user_tweet_relationship['type'].append(data[2])
        user_tweet_relationship['date'].append(data[3])
        
    elif dictionary_to_be_updated == 'user_mentioned_relationship':
        user_mentioned_relationship['user_id'].append(data[0])
        user_mentioned_relationship['mentioned_user_id'].append(data[1])
        user_mentioned_relationship['in'].append(data[2])
    
    elif dictionary_to_be_updated == 'user_used_hashtag':
        user_used_hashtag['user_id'].append(data[0])
        user_used_hashtag['hashtag'].append(data[1])
        user_used_hashtag['in'].append(data[2])
    
    elif dictionary_to_be_updated == 'user_used_url':
        user_used_url['user_id'].append(data[0])
        user_used_url['url'].append(data[1])
        user_used_url['in'].append(data[2])
        
    elif dictionary_to_be_updated == 'tweet_has_url':
        tweet_has_url['tweet_id'].append(data[0])
        tweet_has_url['url'].append(data[1])
        
    elif dictionary_to_be_updated == 'tweet_has_hashtag':
        tweet_has_hashtag['tweet_id'].append(data[0])
        tweet_has_hashtag['hashtag'].append(data[1])

# %% [markdown]
# Now we need to parse through a dataset of Twitter data and extract various information about the users, tweets and relationships between them.
#
# The below code first initializes some dictionaries that will be used to store information about the users, tweets, and relationships between them. Then, it iterates through each tweet in the dataset and extracts information about the user who posted the tweet and the tweet itself. It also checks to see if the tweet is an original tweet or a retweet by looking at the 'referenced_tweets' section. If it is a retweet, it extracts information about the referenced tweet as well.
#
# Next, the script checks if the tweet has any mentions, urls, or hashtags in its 'entities' section. If it does, it extracts information about them and updates the appropriate dictionaries.
#
# Finally, if the tweet has a referenced user and tweet (i.e., it is a retweet), the script extracts information about the referenced user and tweet, updates the appropriate dictionaries, and adds a relationship between the user who posted the original tweet and the referenced user.

# %%
for tweet in data:
    
    # User 0 information - Tweet author info (tweet/reply/quote/retweet)
    user_id_0 = tweet['includes']['users'][0]['id']
    username_0 = tweet['includes']['users'][0]['username']
    user_followers_count_0 = tweet['includes']['users'][0]['public_metrics']['followers_count']

    update_dictionary('users_dict', [user_id_0, username_0, user_followers_count_0])
    
    # Tweet 0 information - Info on the tweet that is referenced in User0.
    tweet_id_0 = tweet['includes']['tweets'][0]['id']
    tweet_text_0 = tweet['includes']['tweets'][0]['text']
    tweet_impression_count_0 = tweet['includes']['tweets'][0]['public_metrics']['impression_count']
    tweet_date_0 = tweet['includes']['tweets'][0]['created_at']
    tweet_replies_0 = tweet['includes']['tweets'][0]['public_metrics']['reply_count']
    update_dictionary('tweets_dict', [tweet_id_0, tweet_text_0, tweet_impression_count_0, tweet_date_0, tweet_replies_0])
        
    # if there is a reference, obtain its type (reply/quote/retweet), otherwise it is an original tweet
    if ('referenced_tweets' in tweet['includes']['tweets'][0]):
        for reference in tweet['includes']['tweets'][0]['referenced_tweets']:
            tweet_0_type = reference['type']
            update_dictionary('user_tweet_relationship', [user_id_0, tweet_id_0, tweet_0_type, tweet_date_0])
    else:
        tweet_0_type = 'tweeted'
        update_dictionary('user_tweet_relationship', [user_id_0, tweet_id_0, tweet_0_type, tweet_date_0])

    # Not all tweets have the 'entities' section (info on mentions, urls hashtags, if any)
    if ('entities' in tweet['includes']['tweets'][0]):
        
        if ('mentions' in tweet['includes']['tweets'][0]['entities']):
            for mention in tweet['includes']['tweets'][0]['entities']['mentions']:
                update_dictionary('user_mentioned_relationship', [user_id_0, mention['id'], tweet_id_0])
                
        # Not all entities contain the 'urls' section
        if ('urls' in tweet['includes']['tweets'][0]['entities']):
            for url in tweet['includes']['tweets'][0]['entities']['urls']:
                update_dictionary('url_dict', [url['expanded_url']])
                update_dictionary('tweet_has_url', [tweet_id_0, url['expanded_url']])
                update_dictionary('user_used_url', [user_id_0, url['expanded_url'], tweet_id_0])
        
        # Not all entities contain the 'hashtags' section
        if ('hashtags' in tweet['includes']['tweets'][0]['entities']):
            for hashtag in tweet['includes']['tweets'][0]['entities']['hashtags']:
                update_dictionary('hashtag_dict', [hashtag['tag']])
                update_dictionary('tweet_has_hashtag', [tweet_id_0, hashtag['tag']])
                update_dictionary('user_used_hashtag', [user_id_0, hashtag['tag'], tweet_id_0])
        
    # If there is a referenced object (i.e. user[1] and tweet[1]) extract all info as before
    if len(tweet['includes']['users']) > 1 and len(tweet['includes']['tweets']) > 1:

        # Extract User 1 node information
        user_id_1 = tweet['includes']['users'][1]['id']
        username_1 = tweet['includes']['users'][1]['username']
        user_followers_count_1 = tweet['includes']['users'][1]['public_metrics']['followers_count']
        
        update_dictionary('users_dict', [user_id_1, username_1, user_followers_count_1])
        
        # Extract User 1 tweet information
        tweet_id_1 = tweet['includes']['tweets'][1]['id']
        tweet_text_1 = tweet['includes']['tweets'][1]['text']
        tweet_impression_count_1 = tweet['includes']['tweets'][1]['public_metrics']['impression_count']
        tweet_date_1 = tweet['includes']['tweets'][1]['created_at']
        tweet_replies_1 = tweet['includes']['tweets'][1]['public_metrics']['reply_count']
     
        update_dictionary('tweets_dict', [tweet_id_1, tweet_text_1, tweet_impression_count_1, tweet_date_1, tweet_replies_1])       
        
        update_dictionary('user_mentioned_relationship', [user_id_0, user_id_1, tweet_id_0])
        
        # if there is a reference, obtain its type. otherwise it is an original tweet
        if ('referenced_tweets' in tweet['includes']['tweets'][1]):
            for reference in tweet['includes']['tweets'][1]['referenced_tweets']:
                tweet_1_type = reference['type']
                update_dictionary('user_tweet_relationship', [user_id_1, tweet_id_1, tweet_1_type, tweet_date_1])
        else:
            tweet_1_type = 'tweeted'
            update_dictionary('user_tweet_relationship', [user_id_1, tweet_id_1, tweet_1_type, tweet_date_1])        
    
        # Not all tweets have the 'entities' section
        if ('entities' in tweet['includes']['tweets'][1]):
            
            if ('mentions' in tweet['includes']['tweets'][1]['entities']):
                for mention in tweet['includes']['tweets'][1]['entities']['mentions']:
                    update_dictionary('user_mentioned_relationship', [user_id_1, mention['id'], tweet_id_1])
            
            # Not all entities contain the 'urls' section
            if ('urls' in tweet['includes']['tweets'][1]['entities']):
                for url in tweet['includes']['tweets'][1]['entities']['urls']:
                    update_dictionary('url_dict', [url['expanded_url']])
                    update_dictionary('tweet_has_url', [tweet_id_1, url['expanded_url']])
                    update_dictionary('user_used_url', [user_id_1, url['expanded_url'], tweet_id_1])
        
            # Not all entities contain the 'hashtags' section
            if ('hashtags' in tweet['includes']['tweets'][1]['entities']):
                for hashtag in tweet['includes']['tweets'][1]['entities']['hashtags']:
                    update_dictionary('hashtag_dict', [hashtag['tag']])
                    update_dictionary('tweet_has_hashtag', [tweet_id_1, hashtag['tag']])
                    update_dictionary('user_used_hashtag', [user_id_1, hashtag['tag'], tweet_id_1])

# %% [markdown]
# ### User node

# %%
users_df = pd.DataFrame(users_dict)

# Drop any potential duplicate values 
users_df = users_df.drop_duplicates(subset=['user_id'], keep='first').reset_index(drop=True)
users_df.head()
# Out:
#                user_id         username  followers_count
# 0  1336660338289340416  Traceyb38701240             2880
# 1           3396828819       1OFFGINGER             5568
# 2             16060248         baski_LA            31165
# 3  1403861754808049666   Khulood_Almani            55457
# 4           2385598159        Kimnology              940

# %% [markdown]
# ### Tweet Node

# %%
tweets_df = pd.DataFrame(tweets_dict)

# Drop any potential duplicate values
tweets_df = tweets_df.drop_duplicates(subset=['tweet_id'], keep='first').reset_index(drop=True)
tweets_df.head()
# Out:
#               tweet_id                                               text  \
# 0  1609340258868686850  RT @1OFFGINGER: Epic Christmas surprise just a...
# 1  1605213170229923841  Epic Christmas surprise just arrived🤩 💃courtes...
# 2  1609339028989673476  RT @Khulood_Almani: ⚡️Internet of Everything (...
# 3  1609138211493711878  ⚡️Internet of Everything (#IoE) in Context\n\n...
# 4  1609340607385714690  RT @femtechconf: Excited to welcome you to #Fe...
#
#    impression_count                tweet_date  reply_count
# 0                 0  2023-01-01T00:06:32.000Z            0
# 1              2171  2022-12-20T14:46:57.000Z            2
# 2                 0  2023-01-01T00:01:39.000Z            0
# 3             16356  2022-12-31T10:43:40.000Z           17
# 4                 0  2023-01-01T00:07:55.000Z            0

# %% [markdown]
# ### URL node

# %%
url_df = pd.DataFrame(url_dict)

# Drop any potential duplicate values
url_df = url_df.drop_duplicates(keep='first').reset_index(drop=True)
url_df.head()
# Out:
#                                                  url
# 0  https://twitter.com/1OFFGINGER/status/16052131...
# 1  https://twitter.com/WeAreTechWomen/status/1605...
# 2  https://twitter.com/Khulood_Almani/status/1609...
# 3                            https://femtechconf.com
# 4  https://twitter.com/darrenplayfordn/status/160...

# %% [markdown]
# ### Hashtag node

# %%
hashtags_df = pd.DataFrame(hashtag_dict)

# Drop any potential duplicate values
hashtags_df = hashtags_df.drop_duplicates(keep='first').reset_index(drop=True)
hashtags_df.head()
# Out:
#            hashtag
# 0          TechMas
# 1  12DaysOfTechMas
# 2      womenintech
# 3      tuesdayvibe
# 4              IoE

# %% [markdown]
# ### User tweeted relationship

# %%
user_tweet = pd.DataFrame(user_tweet_relationship)

# Drop any potential duplicate values
user_tweet = user_tweet.drop_duplicates(keep='first').reset_index(drop=True)
user_tweet.head()
# Out:
#                user_id             tweet_id       type  \
# 0  1336660338289340416  1609340258868686850  retweeted
# 1           3396828819  1605213170229923841     quoted
# 2             16060248  1609339028989673476  retweeted
# 3  1403861754808049666  1609138211493711878    tweeted
# 4           2385598159  1609340607385714690  retweeted
#
#                        date
# 0  2023-01-01T00:06:32.000Z
# 1  2022-12-20T14:46:57.000Z
# 2  2023-01-01T00:01:39.000Z
# 3  2022-12-31T10:43:40.000Z
# 4  2023-01-01T00:07:55.000Z

# %% [markdown]
# ### User used hashtag relationship

# %%
user_used_hashtag_df = pd.DataFrame(user_used_hashtag)

# Drop any potential duplicate values
user_used_hashtag_df = user_used_hashtag_df.drop_duplicates(keep='first').reset_index(drop=True)
user_used_hashtag_df.head()
# Out:
#                user_id          hashtag                   in
# 0  1336660338289340416          TechMas  1609340258868686850
# 1  1336660338289340416  12DaysOfTechMas  1609340258868686850
# 2  1336660338289340416      womenintech  1609340258868686850
# 3  1336660338289340416      tuesdayvibe  1609340258868686850
# 4           3396828819          TechMas  1605213170229923841

# %% [markdown]
# ### Tweet has hashtag relationship

# %%
tweet_has_hashtag_df = pd.DataFrame(tweet_has_hashtag)

# Drop any potential duplicate values
tweet_has_hashtag_df = tweet_has_hashtag_df.drop_duplicates(keep='first').reset_index(drop=True)
tweet_has_hashtag_df.head()
# Out:
#               tweet_id          hashtag
# 0  1609340258868686850          TechMas
# 1  1609340258868686850  12DaysOfTechMas
# 2  1609340258868686850      womenintech
# 3  1609340258868686850      tuesdayvibe
# 4  1605213170229923841          TechMas

# %% [markdown]
# ### User mentioned relationship
#
# Simple mention, reply, retweet or quote

# %%
user_mentioned_df = pd.DataFrame(user_mentioned_relationship)

# Drop any potential duplicate values
user_mentioned_df = user_mentioned_df.drop_duplicates(keep='first').reset_index(drop=True)
user_mentioned_df
# Out:
#                    user_id    mentioned_user_id                   in
# 0      1336660338289340416           3396828819  1609340258868686850
# 1      1336660338289340416           3512757083  1609340258868686850
# 2               3396828819           3512757083  1605213170229923841
# 3                 16060248  1403861754808049666  1609339028989673476
# 4                 16060248             87151593  1609339028989673476
# ...                    ...                  ...                  ...
# 55409  1396652556735111175           3939574932  1614773926428549122
# 55410   893898343180533760  1463156480434081792  1614773968254423040
# 55411  1353637028785770497  1476513861356294144  1614773223094194183
# 55412  1353637028785770497           4876039539  1614773223094194183
# 55413  1353637028785770497   917007096209723392  1614773223094194183
#
# [55414 rows x 3 columns]

# %% [markdown]
# ### User used url relationship

# %%
user_used_url_df = pd.DataFrame(user_used_url)

# Drop any potential duplicate values
user_used_url_df = user_used_url_df.drop_duplicates(keep='first').reset_index(drop=True)
user_used_url_df.head()
# Out:
#                user_id                                                url  \
# 0           3396828819  https://twitter.com/1OFFGINGER/status/16052131...
# 1           3396828819  https://twitter.com/WeAreTechWomen/status/1605...
# 2  1403861754808049666  https://twitter.com/Khulood_Almani/status/1609...
# 3  1217483034888458240                            https://femtechconf.com
# 4  1609335341718335488  https://twitter.com/darrenplayfordn/status/160...
#
#                     in
# 0  1605213170229923841
# 1  1605213170229923841
# 2  1609138211493711878
# 3  1583015496600928259
# 4  1609340979076829185

# %% [markdown]
# ### Tweet has url relationship

# %%
tweet_has_url_df = pd.DataFrame(tweet_has_url)

# Drop any potential duplicate values
tweet_has_url_df = tweet_has_url_df.drop_duplicates(keep='first').reset_index(drop=True)
tweet_has_url_df.head()
# Out:
#               tweet_id                                                url
# 0  1605213170229923841  https://twitter.com/1OFFGINGER/status/16052131...
# 1  1605213170229923841  https://twitter.com/WeAreTechWomen/status/1605...
# 2  1609138211493711878  https://twitter.com/Khulood_Almani/status/1609...
# 3  1583015496600928259                            https://femtechconf.com
# 4  1609340979076829185  https://twitter.com/darrenplayfordn/status/160...

# %% [markdown]
# ### Neo4j

# %% [markdown]
# #### Establish connection
#
# The next step is to establish connection and create a session in python side with the neo4j database. To do so we used the following commands:

# %%
db_connection = GraphDatabase.driver(uri = "bolt://localhost:7687", auth=("neo4j", "test123456"))
session = db_connection.session()

# %% [markdown]
# #### Clear Neo4j
#
# Deleting all nodes and relationships in the database.
#
# To be able to execute the target queries, first we need to initialize the database with the required nodes and relationships. First, we execute the following two commands in order to clean up the database from any previous data:

# %%
# session.run('match (a) -[r] -> () delete a, r')
# session.run('MATCH (n) DETACH DELETE n')

# %% [markdown]
# #### Create Nodes
#
# Given the job which has taken place as described in the previous section, we proceed with the generation of the nodes and the relationships.
#
# The below code is creating a list of statements that will be used to create nodes in the graph database.

# %%
# User nodes
for index, row in users_df.iterrows():
    create_user_statement = 'CREATE (u:User {{userid: \'{}\', username: \'{}\', followers_count: \'{}\'}})' \
        .format(row['user_id'], 
                row['username'], 
                row['followers_count'])
    session.run(create_user_statement)

# Hashtag nodes
for index, row in hashtags_df.iterrows():
    create_hashtag_statement = 'CREATE (h:Hashtag {{hashtag: \'{}\'}})'.format(row['hashtag'])
    session.run(create_hashtag_statement)

# URL nodes
for index, row in url_df.iterrows():
    create_url_statement = 'CREATE (u:URL {{url: \'{}\'}})'.format(row['url'])
    session.run(create_url_statement)

# Tweet nodes
for index, row in tweets_df.iterrows():
    query = "CREATE (t:Tweet {tweet_id: $id, tweet_text: $text, impression_count: $impressions, created_at: $created_at, reply_count: $reply_count})"
    parameters = {'id': row['tweet_id'], 
                  'text': row['text'], 
                  'impressions': row['impression_count'], 
                  'created_at': row['tweet_date'], 
                  'reply_count': row['reply_count']}
    session.run(query, parameters)

# %% [markdown]
# Through [neo4j browser](http://localhost:7474/browser/) it is easy to check if the nodes have been created as expected.

# %% [markdown]
# #### Create relationships
#
# The next step in to create the relationships.

# %%
# Tweet_has_url relationship
for index, row in tweet_has_url_df.iterrows():
    create_tweet_has_url_rel = \
    """MATCH (t:Tweet), (u:URL) WHERE t.tweet_id = \'{}\' AND u.url = \'{}\' CREATE (t)-[tu:HAS_URL]->(u) RETURN type(tu)""" \
    .format(row['tweet_id'], row['url'])
    session.run(create_tweet_has_url_rel)

# Tweet_has_hashtag relationship
for index, row in tweet_has_hashtag_df.iterrows():
    create_tweet_has_hashtag_rel = \
    """MATCH (t:Tweet), (h:Hashtag) WHERE t.tweet_id = \'{}\' AND h.hashtag = \'{}\' CREATE (t)-[th:HAS_HASHTAG]->(h) RETURN type(th)""" \
    .format(row['tweet_id'], row['hashtag'])
    session.run(create_tweet_has_hashtag_rel)

# User_used_url relationship
for index, row in user_used_url_df.iterrows():
    create_user_used_url_rel = \
    """MATCH (user:User), (u:URL) WHERE user.userid = \'{}\' AND u.url = \'{}\' CREATE (user)-[uu:USED_URL]->(u) RETURN type(uu)""" \
    .format(row['user_id'], row['url'])
    session.run(create_user_used_url_rel)

# user RETWEETED, REPLIED, QUOTED, TWEETED_ORIGINAL relationships
for index, row in user_tweet.iterrows():
    if row['type'] == 'retweeted':
        create_user_retweeted_rel = """MATCH (u:User), (t:Tweet) WHERE u.userid = \'{}\' AND t.tweet_id = \'{}\' CREATE (u)-[rt:RETWEETED]->(t) RETURN type(rt)""" \
            .format(row['user_id'], row['tweet_id'])
        session.run(create_user_retweeted_rel)
    elif row['type'] == 'replied_to':
        create_user_replied_rel = """MATCH (u:User), (t:Tweet) WHERE u.userid = \'{}\' AND t.tweet_id = \'{}\' CREATE (u)-[rp:REPLIED]->(t) RETURN type(rp)""" \
            .format(row['user_id'], row['tweet_id'])
        session.run(create_user_replied_rel)
    elif row['type'] == 'quoted':
        create_user_quoted_rel = """MATCH (u:User), (t:Tweet) WHERE u.userid = \'{}\' AND t.tweet_id = \'{}\' CREATE (u)-[qt:QUOTED]->(t) RETURN type(qt)""" \
            .format(row['user_id'], row['tweet_id'])
        session.run(create_user_quoted_rel)
    elif row['type'] == 'tweeted':
        create_user_tweeted_original_rel = """MATCH (u:User), (t:Tweet) WHERE u.userid = \'{}\' AND t.tweet_id = \'{}\' CREATE (u)-[to:TWEETED_ORIGINAL]->(t) RETURN type(to)""" \
            .format(row['user_id'], row['tweet_id'])
        session.run(create_user_tweeted_original_rel)

# user MENTIONED User relationship
for index, row in user_mentioned_df.iterrows():
    create_user_mentioned_rel = """MATCH (u0:User), (u1:User) WHERE u0.userid = \'{}\' AND u1.userid = \'{}\' CREATE (u0)-[mnt:MENTIONED]->(u1) RETURN type(mnt)""" \
            .format(row['user_id'], row['mentioned_user_id'])
    session.run(create_user_mentioned_rel)

# user USED_URL Url relationship
for index, row in user_used_hashtag_df.iterrows():
    create_user_used_hashtag_rel = \
    """MATCH (u:User), (h:Hashtag) WHERE u.userid = '{}' AND h.hashtag = '{}' CREATE (u)-[uh:USED_HASHTAG]->(h) RETURN type(uh)""" \
    .format(row['user_id'], row['hashtag'])
    session.run(create_user_used_hashtag_rel)

# %% [markdown]
# Just like the nodes, it is easy to check that relationships created as expected through [neo4j browser](http://localhost:7474/browser/).

# %% [markdown]
# ### Queries

# %% [markdown]
# * 1) Get the total number of tweets.
#
# * 3) Get the total number of hastags (case insensitive).
#
# * 5) Get the 20 most popular URLs in descending order.
#
# * 7) Get the followers count of each user.
#
# * 9) Get the number of tweets & retweets per hour.
#
# * 11) Get the user with the most replies.
#
# * 13) Get the top-20 hashtags that co-occur with the hashtag that has been used the most.
#
# * 15) Get the most "important" user in the dataset (user Graph algorithms: Pagerangk, Betweenness centrality, etc). You will apply these algorithms in the mention netwwork (which includes retweets).
#
# * 17) For the 5th most important user, get the list of hashtags and URLs that have been posted (if no hashtags or URLs - check another user, e.g. 6th, 7th, etc...).
#
# * 19) Get the user communities that have been created based on the users' interactions and visualize them (Louvain algorithm). (G P)
#
# * Extra query 1: Get the top-10 users who posted the most tweets during the year 2022. In order to count a tweet, it should contain at least one of the top-5 mostly used hashtags of all time.
#
# * Extra query 2: Get the users which have minimum average tweets per day bigger than the average number of tweets of a user per day. Only users with more that 2 tweets per day will be used in order to calculate the average number of tweets per day.

# %% [markdown]
# #### Query 1
#
# ##### Get the total number of tweets
#
# Let's start with a warm up query to checkout the basic syntax. A tweet can be original, reply, retweet or quote. In the following query counts the actuals tweets which exists in the database:

# %%
query = 'MATCH (:User)-[:TWEETED_ORIGINAL]->(t:Tweet) RETURN count(t) as TotalTweets'
output = session.run(query)
print('Number of tweets: ', output.value())
# Out:
# Number of tweets:  [10043]

# %% [markdown]
# #### Query 3
#
# ##### Get the total number of hashtags (case insensitive)
#
# In this query, the solutions required the usage of some functions. In order to achive the counting of unique hashtags the usage of count function and DISTINCT keyword is a must. Also, as the target result should be case insensitive, another function named "toLower" needs to be use to turn every hashtag to lower case. So, to sum up, the query which achieve the solutions can be shown below:

# %%
query = 'MATCH (h:Hashtag) \
         RETURN count(DISTINCT toLower(h.hashtag))'
output = session.run(query)
print('Number of hashtags (case insensitive): ', output.value())
# Out:
# Number of hashtags (case insensitive):  [12613]

# %% [markdown]
# #### Query 5
#
# ##### Get the 20 most popular URLs in descending order
#
# Until now, the executed queries returned a single value. This is not the case with the query we have to answer now. Therefore, we need to figure out how to return mulitple values, or even a table as a result of our query.
#
# Turns out the answer is quite simple: instead of using a single variable in the return clause, we can just add more variables. But in order to print them correctly, a change should also take place on the python side. The usage of "session.value()" command won't return the expected result as it will ignore the second variable. For this reason, the command "session.values()" should be used along with a for loop in order to have a neatly printed result.
#
# Also, to make the results more meaningful, we decided to use the "Order By" clause with "DESC" flag. This clause will order the results based on how many followers each user have in descending order. One detail here, is that the "toInteger" function should be used as "u.followers_count" is a string and the ordering is using the alphabetic order. So the final query can be found below:

# %%
query = 'MATCH (t:Tweet)-[:HAS_URL]->(u:URL) RETURN u.url, count(t) Order by count(t) desc limit 20'
output = session.run(query)
for record in output.values():
    print("URL '{}' has been used in {} tweets".format(record[0], record[1]))
# Out:
# URL 'https://fineartamerica.com' has been used in 119 tweets
# URL 'https://twitter.com/conscientious1o/status/1612372707936718849/photo/1' has been used in 111 tweets
# URL 'https://bit.ly/3WVRK58' has been used in 82 tweets
# URL 'https://twitter.com/UNESCO/status/1611136758325846017/photo/1' has been used in 79 tweets
# URL 'https://amzn.to/3jGb346' has been used in 62 tweets
# URL 'https://womensframe.com/category/health-fitness/pregnancy/' has been used in 56 tweets
# URL 'https://youtu.be/g5n1-hD-x5g' has been used in 56 tweets
# URL 'https://amzn.to/3Q6es8q' has been used in 54 tweets
# URL 'https://doi.org/10.1017/qpb.2021.18' has been used in 54 tweets
# URL 'https://twitter.com/iamojon_/status/1611795133153804288/photo/1' has been used in 54 tweets
# URL 'https://doi.org/10.1515/jib-2019-0005' has been used in 51 tweets
# URL 'https://amzn.to/3Z5iMbZ' has been used in 50 tweets
# URL 'http://bit.ly/GreenITNvidia' has been used in 49 tweets
# URL 'https://twitter.com/Equal_Fights/status/1613791501787566080/video/1' has been used in 45 tweets
# URL 'https://buff.ly/2FXR37r' has been used in 39 tweets
# URL 'https://twitter.com/Equal_Fights/status/1613813839870451713/video/1' has been used in 38 tweets
# URL 'https://twitter.com/Equal_Fights/status/1614119793879121920/video/1' has been used in 37 tweets
# URL 'https://iotpractitioner.com/iot-premier-league-and-iot-champions-league-week-45-and-2022-final-standings-and-mvp-awards/' has been used in 31 tweets
# URL 'https://twitter.com/Equal_Fights/status/1614680829552201729/video/1' has been used in 31 tweets
# URL 'https://bit.ly/3iu3kFB' has been used in 30 tweets

# %% [markdown]
# #### Query 7
#
# ##### Get the followers count of each user
#
# The query starts with the `MATCH` clause which specifies that we want to match all nodes labeled `User`. Here, `u` is an alias for the `User` node.
#
# The `RETURN` clause specifies the properties of the `User` node that we want to return as output. Here, we want to return the `username`, `userid`, and `followers_count` properties of each `User` node.
#
# The `as` keyword is used to provide aliases to the properties, which makes it easier to read and understand the output.
#
# The result of the query is a table that contains the username, user ID, and followers count for each User node in the graph database.
#
# The `output` variable is assigned the result of the query after it is executed using the `session.run()` method. The result is then converted into a Pandas DataFrame using the `pd.DataFrame()` method and assigned to the `followers_count_df` variable.
#
# Overall, this query is useful for extracting basic information about users in a graph database and can be a starting point for more complex analysis and visualization tasks.

# %%
query = 'MATCH (u:User) RETURN toInteger(u.followers_count) as fc, u.username Order By fc desc'
output = session.run(query)
for val in output.values():
    print('User {} has {} followers'.format(val[1], val[0]))
# Out:
# User elonmusk has 128284304 followers
# User narendramodi has 86388755 followers
# User Twitter has 65457040 followers
# User MileyCyrus has 46930973 followers
# User deepikapadukone has 27242900 followers
# User Reuters has 25737040 followers
# User Forbes has 18710206 followers
# User timesofindia has 14678419 followers
# User UberFacts has 13620478 followers
# User thekiranbedi has 12185146 followers
# User TEDTalks has 11359357 followers
# User sardesairajdeep has 8960481 followers
# User Windows has 7794614 followers
# User IndiaToday has 6246901 followers
# User TheRealPCB has 5818033 followers
# User Javedakhtarjadu has 4786676 followers
# User wef has 4338609 followers
# User FLOTUS has 4182244 followers
# User amnestyusa has 4173233 followers
# User UNHumanRights has 4022080 followers
# User WorldBank has 3787717 followers
# User Jemima_Khan has 3749271 followers
# User inquirerdotnet has 3717912 followers
# User UNESCO has 3675313 followers
# User Naveen_Odisha has 3529236 followers
# User ColorsTV has 3513392 followers
# User StephMcMahon has 3271608 followers
# User CoinDesk has 3052202 followers
# User PIB_India has 2781544 followers
# User okx has 2692685 followers
# User Hadithoftheday has 2679568 followers
# User Ripple has 2622839 followers
# User melindagates has 2543713 followers
# User Nature has 2481038 followers
# User UN_Women has 2242549 followers
# User bsindia has 2232593 followers
# User DainikBhaskar has 2207879 followers
# User PTTVOnlineNews has 2066159 followers
# User chartdata has 1920151 followers
# User libsoftiktok has 1893698 followers
# User Cointelegraph has 1864960 followers
# User Mrwhosetheboss has 1746203 followers
# User APompliano has 1644524 followers
# User coingecko has 1573642 followers
# User RanaAyyub has 1554862 followers
# User KirenRijiju has 1516314 followers
# User historyinmemes has 1467971 followers
# User gate_io has 1443849 followers
# User goldenglobes has 1438679 followers
# User Keir_Starmer has 1402093 followers
# User moneycontrolcom has 1372367 followers
# User FightHaven has 1347198 followers
# User glamourmag has 1302202 followers
# User MMCrypto has 1299084 followers
# User priyankac19 has 1258883 followers
# User ELLEINDIA has 1235302 followers
# User mmpadellan has 1183144 followers
# User BJP4MP has 1171651 followers
# User AskAnshul has 1130587 followers
# User sofizamolo has 1129895 followers
# User CNBCTV18News has 1089825 followers
# User MMAFighting has 1089060 followers
# User Mechilambre has 1052867 followers
# User BBCPolitics has 1000618 followers
# User BLACKPINKGLOBAL has 1000438 followers
# User Outlookindia has 240162 followers
# User investindia has 239921 followers
# User KHayhoe has 235289 followers
# User realTuckFrumper has 234559 followers
# User adamonzon has 232190 followers
# User StackOverflow has 230460 followers
# User CanadainIndia has 227015 followers
# User HelenClarkNZ has 226798 followers
# User Salansar1 has 226042 followers
# User DaCryptoGeneral has 218208 followers
# User MoRD_GoI has 217110 followers
# User BMGFIndia has 216702 followers
# User TimmermansEU has 216653 followers
# User OfficeOfLGJandK has 216004 followers
# User UNYouthEnvoy has 214497 followers
# User BSCGemsAlert has 212565 followers
# User drthema has 210275 followers
# User UNDPSomalia has 207110 followers
# User ThamizhachiTh has 205981 followers
# User jsteenhuisen has 205958 followers
# User EmmaNyra has 205891 followers
# User GirlsinTech has 205135 followers
# User MrBigWhaleREAL has 204465 followers
# User ficci_india has 202932 followers
# User EmmaBostian has 202916 followers
# User Rashakelej has 200713 followers
# User NJLahori has 197979 followers
# User MilfsnCum has 197801 followers
# User alhanda has 196518 followers
# User womenintech has 191844 followers
# User BiggBoss_Tak has 191835 followers
# User BobRae48 has 190969 followers
# User SydesJokes has 190231 followers
# User altcryptocom has 190062 followers
# User NevilleSouthall has 189355 followers
# User unpublications has 188220 followers
# User Yourpop8 has 187805 followers
# User EntMagazineME has 187563 followers
# User CIOonline has 184105 followers
# User UNVolunteers has 182963 followers
# User tzDiscovery has 182029 followers
# User CertiKCommunity has 176329 followers
# User cryptojack has 176112 followers
# User NeedyGirlsx has 174403 followers
# User TVRailey has 173495 followers
# User mrssiren has 171951 followers
# User Punam_Keshari01 has 171276 followers
# User diprjk has 168769 followers
# User mfespinosaEC has 168048 followers
# User MsAvaArmstrong has 166077 followers
# User JavedNLaghari has 164100 followers
# User HarjitSajjan has 163881 followers
# User amritabhinder has 161579 followers
# User CarlineIllusion has 160438 followers
# User _iamnaaz_ has 155650 followers
# User eu_near has 155369 followers
# User wacom has 153092 followers
# User MetaOpenSource has 151833 followers
# User GPforEducation has 151814 followers
# User AirbusCareers has 151687 followers
# User UrmilaMatondkar has 151045 followers
# User SwissCognitive has 150120 followers
# User AltCryptoLion has 149784 followers
# User NanhiKali has 149772 followers
# User TheGlobalGoals has 148533 followers
# User womensaid has 147935 followers
# User unwomenchief has 147769 followers
# User WBPubs has 146913 followers
# User Kasungwa_ has 146359 followers
# User detectfights has 145402 followers
# User UNWTO has 144981 followers
# User ShamikaRavi has 144861 followers
# User JakeGagain has 144471 followers
# User panasonic has 143585 followers
# User adamsconsulting has 140587 followers
# User BiconomyCom has 138742 followers
# User DigiFinex has 138384 followers
# User TheAnitaErskine has 137441 followers
# User Strategy_Gal has 137408 followers
# User LakshmyRamki has 137015 followers
# User DrShobha has 136615 followers
# User sallyeaves has 134789 followers
# User FD_Nieuws has 133610 followers
# User LOrealGroupe has 133608 followers
# User IFPRI has 133506 followers
# User globalcompact has 132749 followers
# User reshmasaujani has 131923 followers
# User DeepLearn007 has 131031 followers
# User ipfconline1 has 130068 followers
# User asana has 129344 followers
# User ger_trends has 129241 followers
# User IRENA has 128715 followers
# User WomenDeliver has 128037 followers
# User paul_cude has 127817 followers
# User SpirosMargaris has 127526 followers
# User reliefweb has 123451 followers
# User SteGiannini has 122654 followers
# User orfonline has 122353 followers
# User Ralvero has 122324 followers
# User MelissaOnline has 121854 followers
# User _atanas_ has 121767 followers
# User PunjabPoliceCPO has 120010 followers
# User MirrorNow has 120004 followers
# User AdaniFoundation has 119963 followers
# User Astro_Cady has 119794 followers
# User JoyDoreenBiira has 119561 followers
# User LunaClassicHQ has 118720 followers
# User jamesvgingerich has 117918 followers
# User TheRabbitHole84 has 117728 followers
# User ArmandPeri has 117652 followers
# User Maersk has 117569 followers
# User PhDVoice has 117131 followers
# User 4womeninscience has 116118 followers
# User KentPage has 114861 followers
# User SimonCocking has 114052 followers
# User LarryDevine has 113713 followers
# User MAKERSwomen has 113129 followers
# User FoxCryptoBSC has 113063 followers
# User devex has 111032 followers
# User abdulla_shahid has 110897 followers
# User vineetasng has 110452 followers
# User TheAltcoinCom has 110327 followers
# User UNDP_Pakistan has 110046 followers
# User Nicochan33 has 109637 followers
# User Crypto__Diva has 108763 followers
# User Sana____Sweet has 108756 followers
# User CryptoKoalaBtc has 107406 followers
# User atari has 105902 followers
# User Sernatur has 104765 followers
# User UNDP_India has 104701 followers
# User NextBillion has 104403 followers
# User yourcryptodj has 104042 followers
# User soslalisa has 103953 followers
# User ITU has 101773 followers
# User PTIPeshawar has 101364 followers
# User SDG2030 has 100402 followers
# User careersingov has 100079 followers
# User BollySpy has 99924 followers
# User HaroldSinnott has 99910 followers
# User HadrielCamille has 99738 followers
# User YvesMulkers has 98994 followers
# User NikkiSiapno has 98913 followers
# User mvollmer1 has 98477 followers
# User paoloigna1 has 96810 followers
# User DoPTGoI has 96583 followers
# User AltGemHunter has 96008 followers
# User Advjalila has 95827 followers
# User CryptoInsightsX has 95671 followers
# User JamieJackson___ has 95224 followers
# User UiPath has 94973 followers
# User LogicalIndians has 94057 followers
# User USAndMumbai has 94054 followers
# User PMGDISHA has 93617 followers
# User PlanGlobal has 93576 followers
# User arunpudur has 93502 followers
# User drishtiiaseng has 93285 followers
# User Fisher85M has 93086 followers
# User CTATech has 92799 followers
# User Nasdaq has 92493 followers
# User craignewmark has 91716 followers
# User jeffkagan has 91333 followers
# User colors_infinity has 91235 followers
# User jblefevre60 has 91196 followers
# User MrBossMan90 has 91177 followers
# User MQuigley1963 has 90611 followers
# User akidcalledbeast has 90548 followers
# User UNDPYemen has 89268 followers
# User cindygallop has 89133 followers
# User TechNative has 89104 followers
# User anujdhar has 88822 followers
# User ECOWARRIORSS has 87006 followers
# User SomPundit has 86806 followers
# User AltcoinWorldcom has 86732 followers
# User Advaidism has 86601 followers
# User ChristineMilne has 86553 followers
# User RepresentPledge has 85237 followers
# User cgledhill has 85162 followers
# User ians_india has 84992 followers
# User agnesbinagwaho has 84416 followers
# User bmurphypointman has 84251 followers
# User EntrepreneurOrg has 84113 followers
# User USAinUK has 83675 followers
# User cracker_hole has 83596 followers
# User IDS_UK has 83007 followers
# User LatinaCasanova has 82802 followers
# User OECD_Centre has 81470 followers
# User sakurasasku has 35363 followers
# User WomenScienceDay has 35276 followers
# User iamHassanSajid has 35232 followers
# User jaihind2002 has 35173 followers
# User GirlsGlobe has 35132 followers
# User Spatial_io has 35035 followers
# User DigitalPromise has 34916 followers
# User LatersBabyUK has 34857 followers
# User LauraSavino747 has 34802 followers
# User JayHari23 has 34704 followers
# User harmony_kent has 34580 followers
# User SheCodeAfrica has 34558 followers
# User ghumare64 has 34511 followers
# User charliesbot has 34355 followers
# User Strat_AI has 34144 followers
# User ametsoc has 34032 followers
# User CGAP has 34007 followers
# User Primary_Immune has 33996 followers
# User arjenvanberkum has 33861 followers
# User AnthonyRochand has 33844 followers
# User CynthiaUmurisa has 33819 followers
# User AkezaGermaine has 33778 followers
# User justkelly_ok has 33728 followers
# User RosyCoaching has 33711 followers
# User drsharwood has 33681 followers
# User patarimusic has 33637 followers
# User Eli_Krumova has 33613 followers
# User AltGemsAlert has 33612 followers
# User AngliaRuskin has 33594 followers
# User Momademia has 33556 followers
# User MakhanSingHindU has 33545 followers
# User USAIDSouthSudan has 33531 followers
# User openSAP has 33502 followers
# User naomitimperley has 33472 followers
# User OEA_Cyber has 33468 followers
# User helene_wpli has 33442 followers
# User ravikarkara has 33392 followers
# User Siftedeu has 33332 followers
# User ManagerTactical has 33303 followers
# User Mum1City has 33195 followers
# User sheilagregoire has 33178 followers
# User TinaTinde has 33174 followers
# User KarlaforFlorida has 33100 followers
# User itzareous has 33086 followers
# User Geology_History has 33012 followers
# User padangbolasepak has 32974 followers
# User BITC has 32941 followers
# User ARG_Mara has 32896 followers
# User JayeJaybird54 has 32885 followers
# User CanHCPakistan has 32876 followers
# User JointSDGFund has 32638 followers
# User _TechMode has 32536 followers
# User beatricedegraaf has 32512 followers
# User woman_kind has 32491 followers
# User MurapaG has 32379 followers
# User Latvian_MFA has 32378 followers
# User aishaattiku has 32138 followers
# User ICNurses has 31651 followers
# User IWMI_ has 31579 followers
# User NeerjaBirla has 31528 followers
# User queencryptooo has 31521 followers
# User ITUSecGen has 31468 followers
# User dawn_images has 31439 followers
# User nickisnpdx has 31409 followers
# User pakstockexgltd has 31286 followers
# User cgalgale has 31250 followers
# User joshfunkbooks has 31171 followers
# User baski_LA has 31165 followers
# User AdamRogers2030 has 31003 followers
# User NiceEllah has 30997 followers
# User TheHighway2AI has 30943 followers
# User SangwaSifa has 30907 followers
# User FitzgeraldFrncs has 30775 followers
# User KaceyKells has 30755 followers
# User IndianEmbTokyo has 30722 followers
# User OECDdev has 30668 followers
# User etfcom has 30587 followers
# User WomenInTechShow has 30562 followers
# User KNMishra_ has 30508 followers
# User FAOSDGs has 30468 followers
# User ivanabacik has 30463 followers
# User intelligentHQ has 30376 followers
# User MerckFoundation has 30362 followers
# User WorldMovieAward has 30356 followers
# User femalequotient has 30285 followers
# User rockethulsey has 30113 followers
# User joan_cpc has 30003 followers
# User IA_UXJOBS has 29931 followers
# User AndreasHale has 29830 followers
# User ShriBalaJi_ has 29798 followers
# User frontlineaids has 29749 followers
# User CarryCockburn has 29746 followers
# User ModestyQueen19 has 29736 followers
# User InorgChem has 22046 followers
# User the_prbb has 21987 followers
# User SChasse49 has 21955 followers
# User vanyaradzayi has 21948 followers
# User nestlepakistan has 21929 followers
# User IDivyaShukla_ has 21871 followers
# User UNCDF has 21830 followers
# User SocialTMantra has 21819 followers
# User labordeolivier has 21733 followers
# User advocatetinashe has 21704 followers
# User TATrader_Alan has 21697 followers
# User puppyjohn1999 has 21690 followers
# User SMWLagos has 21631 followers
# User _AllAboutData has 21614 followers
# User Sxmmediagroup has 21587 followers
# User UNDPArabStates has 21579 followers
# User DocDre has 21576 followers
# User REA_research has 21558 followers
# User tocho_sanro has 21471 followers
# User NumsOfficial has 21399 followers
# User Be_Herrero has 21380 followers
# User BreeanSunny has 21378 followers
# User bizsavvycoach has 21341 followers
# User ryan_owan_FX has 21341 followers
# User CryptoTechWomen has 21320 followers
# User ParisFinForum has 21320 followers
# User shashiwhocodes has 21275 followers
# User vijayjdarda has 21245 followers
# User efipm has 21065 followers
# User ArunachalTsm has 21029 followers
# User blanketcrap has 20939 followers
# User 5Naureen has 20912 followers
# User ssingapuri has 20899 followers
# User KendoUI has 20859 followers
# User akosua_amoabea has 20845 followers
# User GinaForAustin has 20722 followers
# User Paris_Dauphine has 20691 followers
# User IPPFAR has 20688 followers
# User DigitalMasterCh has 20681 followers
# User jetcitystar has 20670 followers
# User womenadvocate has 20591 followers
# User niksandnacs has 20522 followers
# User mollie_hearts has 20506 followers
# User sramana has 20480 followers
# User iDigitalKingdom has 20472 followers
# User WendyMadzura has 20453 followers
# User CanlHelpYou has 20452 followers
# User edwell_khide has 20415 followers
# User eige_eu has 20317 followers
# User CoffeTechnology has 20287 followers
# User FutureOurWork has 20273 followers
# User MaxDigitalSight has 20245 followers
# User TravelistaStyle has 20215 followers
# User TheDigitalJob has 20203 followers
# User arielSTRABONI has 20198 followers
# User GlobalSpotlight has 20181 followers
# User bankimooncentre has 20132 followers
# User k3r3n3 has 20131 followers
# User Fos_Feminista has 20116 followers
# User TechEqualizer has 20100 followers
# User WCHospital has 20059 followers
# User chiziaruhoma has 20051 followers
# User ShibArmy_4Life has 20006 followers
# User tlloydjones has 19999 followers
# User TCS_Europe has 19971 followers
# User UNICBeirut has 19961 followers
# User 100xAltcoinGems has 19949 followers
# User WeAreTechWomen has 19936 followers
# User DaveWays_ has 19905 followers
# User AU_WGYD has 19821 followers
# User RealTimeChem has 19792 followers
# User LMMiddleEast has 19763 followers
# User sonal_mansingh has 19727 followers
# User Katrinavision has 19725 followers
# User RakeshTiwari___ has 19707 followers
# User sec_r0 has 19704 followers
# User CerrJ has 19646 followers
# User pariforindia has 19638 followers
# User BLACKandSTEM has 19627 followers
# User LesleyannIrvin1 has 19569 followers
# User icacoop has 19563 followers
# User InPowerWomen has 19511 followers
# User SmartBizInsight has 19392 followers
# User ShahlaGondal has 19391 followers
# User OpenDataWatch has 19347 followers
# User penndragonArt has 19331 followers
# User geoscientistmag has 19293 followers
# User StrokeDriven has 19277 followers
# User PlanNederland has 19242 followers
# User Timberry has 19197 followers
# User UN_Ukraine has 19179 followers
# User kobiwaynejr has 19124 followers
# User matjendav4 has 19118 followers
# User vinirish has 19092 followers
# User djjsworld has 19017 followers
# User DataSocietyTW has 19012 followers
# User UN_Lebanon has 18948 followers
# User _IHREC has 18882 followers
# User RussShaw1 has 18877 followers
# User unixdoss has 18854 followers
# User zerotomasteryio has 18788 followers
# User BroadcomVSM has 18738 followers
# User WBG_DigitalDev has 18716 followers
# User JustOldLou has 18672 followers
# User BeverlyFolkers has 18576 followers
# User sukeji_handa has 18553 followers
# User MikeGPTweets has 18449 followers
# User ClimateOutreach has 18446 followers
# User AwakeningTrue has 18414 followers
# User RockinFreelance has 18370 followers
# User mkatouah has 18360 followers
# User rishi_suri has 18345 followers
# User NCIResearchCtr has 18344 followers
# User CarleyWarwen has 18262 followers
# User StartupNScaleup has 18253 followers
# User NBathily has 18240 followers
# User CKyobutungi has 18232 followers
# User bandanarana2014 has 18231 followers
# User adriansalter315 has 18229 followers
# User NowPammsy has 18227 followers
# User stephelisecarls has 18219 followers
# User kirti_012 has 18209 followers
# User NicolaWatson13 has 18205 followers
# User C20EG has 18189 followers
# User helloalludo has 18142 followers
# User NCMIndiaa has 18107 followers
# User GulfBusiness has 18087 followers
# User RELXHQ has 18050 followers
# User NavneetSagarsIT has 18049 followers
# User A_MateenAnsari has 17979 followers
# User technovation has 17973 followers
# User anymatnft has 17941 followers
# User GimonoMaureen has 17931 followers
# User JRichmondstyle has 17838 followers
# User kalydeoo has 17795 followers
# User ShivaaBJYM has 17780 followers
# User Itamaraty_EN has 17756 followers
# User UNIDIR has 17755 followers
# User BentleySystems has 17746 followers
# User RadioChinarFM has 17744 followers
# User DeogharPolice has 17733 followers
# User neemalugangira has 17731 followers
# User BlessingsDigha has 17717 followers
# User FDS_NaturallyMe has 17693 followers
# User R0sielewis has 17681 followers
# User ChrisDeGress has 17671 followers
# User enisa has 17621 followers
# User Anniecoops has 17588 followers
# User _LataAga1 has 17576 followers
# User WeAreTheCity has 17568 followers
# User UKRinUN has 17529 followers
# User nomoreslaves has 17528 followers
# User VeereVishal has 17467 followers
# User DebbiAlmontaser has 17420 followers
# User intesasanpaolo has 17419 followers
# User rk70534 has 17410 followers
# User SayItForwardNow has 17401 followers
# User t3rwix has 17388 followers
# User agingdoc1 has 17349 followers
# User benniekara has 17348 followers
# User AlleyWatch has 17330 followers
# User komallsalman has 17327 followers
# User WaterTrends has 17289 followers
# User UswaeZainab3 has 17269 followers
# User ShelleyZalis has 17252 followers
# User alokmittal001 has 17250 followers
# User CarolOdero has 17240 followers
# User IM_SarikaDixiT has 17231 followers
# User AlphaARachman has 17166 followers
# User michaldivon has 17158 followers
# User CanHCSriLanka has 17132 followers
# User JWFoundation_ has 17044 followers
# User TheStatesmanLtd has 17038 followers
# User SMUReforms has 16978 followers
# User dr_shizu_ has 16973 followers
# User capegreco has 16957 followers
# User jyotiTpandey05 has 16932 followers
# User ScientistFemale has 16921 followers
# User tizianacampodon has 16897 followers
# User TheHansIndiaWeb has 16881 followers
# User The_Last_Hurdle has 16870 followers
# User LearnSuccessNow has 16846 followers
# User steviweavi has 16829 followers
# User SteinbrinkLaura has 16792 followers
# User TonyaWrites has 16778 followers
# User vintananda has 16756 followers
# User RLDI_Lamy has 16732 followers
# User ArtistRTweeters has 16675 followers
# User LawTimes has 16652 followers
# User Kizaale has 16603 followers
# User IrmaRaste has 16586 followers
# User LydiaTHaPoet has 16504 followers
# User Marcoable has 16477 followers
# User LowellRoemer has 16475 followers
# User ReaktorNow has 16471 followers
# User khanna248 has 16471 followers
# User LovesVintage43 has 16466 followers
# User JenniferGarrett has 16447 followers
# User msonu4511 has 16433 followers
# User rr_edmonds has 16416 followers
# User SahelHKJ has 16408 followers
# User undpmalawi has 16371 followers
# User BPACofficial has 16367 followers
# User GaleStanley has 16360 followers
# User milos_agathon has 16294 followers
# User Womenonboards has 16290 followers
# User TheTechRally has 16289 followers
# User principal has 16250 followers
# User CisoOnlineClub has 16227 followers
# User RoopaDhatt has 16220 followers
# User sachina04596967 has 16183 followers
# User kentbuse has 16177 followers
# User NixonJoseph1708 has 16148 followers
# User MirahMirah_265 has 16147 followers
# User pass_blue has 16125 followers
# User ravikikan has 16111 followers
# User andrewmorrisuk has 16085 followers
# User EngageState has 16044 followers
# User Gaurai1984 has 16030 followers
# User ThePeoplesHubHQ has 16018 followers
# User thegirdlengr has 16003 followers
# User unwomenEU has 15996 followers
# User mantisgallery has 15995 followers
# User 100DaysOf2020 has 15983 followers
# User MCChildsBookDay has 15970 followers
# User ABLpk has 15940 followers
# User CAREGlobal has 15921 followers
# User MissPhilbin has 15904 followers
# User rondelle10_b has 15893 followers
# User Marthacarroline has 15890 followers
# User laalaakhaan has 15886 followers
# User FranceONUGeneve has 15837 followers
# User bar_zie has 15833 followers
# User datagenius has 15782 followers
# User leticiakawano has 15749 followers
# User globalactplan has 15717 followers
# User artyny59 has 15703 followers
# User Zatomas has 15683 followers
# User muxoke has 15645 followers
# User Analyticsindiam has 15613 followers
# User HorizonMagEU has 15613 followers
# User fleejack has 15608 followers
# User deecaffari has 15567 followers
# User PanziUSA has 15550 followers
# User mia31b has 15547 followers
# User TaxwriteoffNft has 15505 followers
# User brijeshchaodhry has 15488 followers
# User FIGOHQ has 15467 followers
# User sushmatyagi28 has 15456 followers
# User DeVilbissPeter has 15456 followers
# User DrAnjaliTai has 15427 followers
# User UrsBolt has 15417 followers
# User targetjobsUK has 15414 followers
# User ElizabethGore has 15411 followers
# User Amdocs has 15404 followers
# User rajesharmahisar has 15399 followers
# User FIP_org has 15397 followers
# User geekyouup has 15381 followers
# User Ganpats96284469 has 15356 followers
# User cooperazione_it has 15354 followers
# User RukundoChrist14 has 15344 followers
# User StaffPodcast has 15312 followers
# User cw1985 has 15269 followers
# User dt_next has 15252 followers
# User joemckendrick has 15209 followers
# User sonu_monika has 15185 followers
# User Sachin55476477 has 15140 followers
# User ambreen has 15127 followers
# User NeedhiBhalla has 15113 followers
# User MiningReview has 15100 followers
# User TheThe1776 has 15095 followers
# User IcelandUN has 15089 followers
# User TechIsHiring has 15050 followers
# User beingkarmin has 13314 followers
# User ddskier has 13307 followers
# User Rekhha_kara has 13270 followers
# User SwaziDailyNews has 13258 followers
# User XZPwEDVhHH37i3C has 13233 followers
# User deshybrax has 13232 followers
# User dreapizziconi has 13198 followers
# User GNB_Uganda has 13157 followers
# User Lets_B_Real has 13143 followers
# User vaastavngo has 13127 followers
# User Stevens18Clint has 13084 followers
# User iangertler has 13079 followers
# User BBNTimes_en has 13056 followers
# User JanthanaK has 13047 followers
# User BetterThan_Cash has 13029 followers
# User Sahu_Choudhary1 has 13015 followers
# User CRYPTO__BLACK has 13013 followers
# User Insane_tweetz has 13002 followers
# User hanif_dawar has 12993 followers
# User sunil_abraham has 12958 followers
# User AdbPartnerships has 12951 followers
# User coolheadtech has 12942 followers
# User DisfoldDotCom has 12936 followers
# User MonikaNFT has 12929 followers
# ...
# User win_morocco has 2 followers
# User MahimaM43019323 has 2 followers
# User PoojaPa34065764 has 2 followers
# User anjali1rw has 2 followers
# User monitar14 has 2 followers
# User TaituCollection has 2 followers
# User ArchanaPuri12 has 2 followers
# User SumitUp18804481 has 2 followers
# User JuvalPrinsh has 2 followers
# User sahil11441932 has 2 followers
# User theainomad has 2 followers
# User kliq4life has 2 followers
# User AmranMo04551708 has 2 followers
# User LegaultLelay has 2 followers
# User J85096971 has 2 followers
# User Shyamabhatk1 has 2 followers
# User rjsmultani has 2 followers
# User b_nesuhu has 2 followers
# User SatyaNa83447072 has 2 followers
# User faenterprises66 has 2 followers
# User AWCDigitalMedia has 2 followers
# User shyam88849610 has 2 followers
# User srishti02494392 has 2 followers
# User RaviKum21328340 has 2 followers
# User AmitRaj46892375 has 2 followers
# User eadamah_abi has 2 followers
# User Roudost has 2 followers
# User LifeStoriesMarc has 2 followers
# User TanTanBofficial has 2 followers
# User RajRoy06369157 has 2 followers
# User AbrarSi51183651 has 2 followers
# User Isoquant89 has 2 followers
# User sahilkr91504736 has 2 followers
# User _sheinspire has 2 followers
# User lundyson has 2 followers
# User ShopLove2wear has 2 followers
# User Nikitabhutani24 has 2 followers
# User YogiDasM1 has 2 followers
# User PankajV23480636 has 2 followers
# User BawseChiques has 2 followers
# User ALMAROW1 has 2 followers
# User lekanamazing_ has 2 followers
# User DolyVarshney has 2 followers
# User OliverG28596964 has 2 followers
# User mitra_tohidi has 2 followers
# User MarkusSepp1 has 1 followers
# User sasha2rob has 1 followers
# User starters_diary has 1 followers
# User ChitturiRajesh8 has 1 followers
# User SWoL274 has 1 followers
# User vero_lens has 1 followers
# User poonam_digital has 1 followers
# User yznanee has 1 followers
# User godcreatewoman has 1 followers
# User hockeyAI_ has 1 followers
# User DayaYad79977681 has 1 followers
# User meetverma2116 has 1 followers
# User jalphacenturion has 1 followers
# User xmclarenn has 1 followers
# User Shabi87333821 has 1 followers
# User Gurmeet25465327 has 1 followers
# User BcdeInitiative has 1 followers
# User __Roboter has 1 followers
# User KakotyNeha has 1 followers
# User SUSMITA73089797 has 1 followers
# User Robita02280922 has 1 followers
# User rabitadevi4 has 1 followers
# User One_Sanatan has 1 followers
# User jinkaz2013 has 0 followers
# User schwaby50001 has 0 followers
# User JohnChr66372593 has 0 followers
# User AnnieV41 has 0 followers
# User NIGGLIT4rent has 0 followers
# User angelbnmotibaoX has 0 followers
# User HasiriSamane has 0 followers
# User pisceanchild has 0 followers
# User SmitPat58454540 has 0 followers
# User myles_milliken has 0 followers
# User AlexceeRobert has 0 followers
# User SDaddyxd has 0 followers
# User BoneDad92218757 has 0 followers
# User Anon_Vwer has 0 followers
# User CodyRamsay5 has 0 followers
# User EasleyColl has 0 followers
# User cornyahhh has 0 followers
# User RobertKnittel2 has 0 followers
# User dilip09 has 0 followers
# User AKonpien has 0 followers
# User saxena_sanatan has 0 followers
# User PainfulTruth007 has 0 followers
# User Mamta_sharma18 has 0 followers
# User Eljefe9428 has 0 followers
# User 4ukasha has 0 followers
# User satyaprasadkop2 has 0 followers
# User Arajsingh10 has 0 followers
# User RiddhiV01614452 has 0 followers
# User Digvija19851578 has 0 followers
# User Nozi_flowers has 0 followers
# User m_a_scorringe has 0 followers
# User Equalist_me has 0 followers
# User DemagogueKtg has 0 followers
# User PenelopeBreton3 has 0 followers
# User JaySing41250711 has 0 followers
# User weiler_MC has 0 followers
# User RahulDwivedi14 has 0 followers
# User carminecleiton1 has 0 followers
# User AishaTahir11 has 0 followers
# User TatianaErho1 has 0 followers
# User olaf_maganda has 0 followers
# User AzatCem1987 has 0 followers
# User molala797 has 0 followers
# User TrumpFanLi has 0 followers
# User bryan_phong has 0 followers
# User OTD_IN_HISTORY has 0 followers
# User haytham_salaam has 0 followers
# User CyberInstincts1 has 0 followers
# User narendrajaat829 has 0 followers
# User woodruff_end has 0 followers
# User Pariharrajat01 has 0 followers
# User Premjee85076808 has 0 followers
# User Anshika___15 has 0 followers
# User JANAKINAGARAJA2 has 0 followers
# User claudie_7leaves has 0 followers
# User LewisRo94481431 has 0 followers
# User SuperCh98326247 has 0 followers
# User Hrmantra_ has 0 followers
# User upliftingher has 0 followers
# User dafreshapparel has 0 followers
# User Codysboutique has 0 followers
# User Jagdish19848104 has 0 followers
# User alifirdous321 has 0 followers
# User pordiridmccoc has 0 followers
# User Mahendr47844939 has 0 followers
# User JSchafef has 0 followers
# User cacembradshaa has 0 followers
# User pukarra63507574 has 0 followers
# User mbrqueritmhubeu has 0 followers
# User aessijvicv has 0 followers
# User aotben has 0 followers
# User RhettChapman1 has 0 followers
# User fayaz20malik has 0 followers
# User lauresvillalob1 has 0 followers
# User KluaVivek has 0 followers
# User joleekhaiki has 0 followers
# User chccvguthrih has 0 followers
# User wilbeqblanck has 0 followers
# User FoundationLally has 0 followers
# User shopduh has 0 followers
# User aniket_ghale has 0 followers
# User DbwnQ has 0 followers
# User helenkblajkensh has 0 followers
# User SAxteq has 0 followers
# User dottefij has 0 followers
# User ercvrodr has 0 followers
# User BYalagud has 0 followers
# User SatendraSaxen10 has 0 followers
# User kaiamuslanahom has 0 followers
# User SandraD80289898 has 0 followers
# User VikashK92805474 has 0 followers
# User Sandeep11148811 has 0 followers
# User KapasiSaahir has 0 followers
# User AcadbuddyL has 0 followers
# User NationPawnee has 0 followers
# User Zalbu3 has 0 followers
# User Abhijit99839258 has 0 followers
# User metadigisphere has 0 followers
# User mobixweb has 0 followers
# User haku_nagi00 has 0 followers
# User SubbarayanK5 has 0 followers
# User streetJournali6 has 0 followers
# User MASofi12984509 has 0 followers
# User YuliaNerdsbay has 0 followers
# User SandipC94358214 has 0 followers
# User Girlsclubbiz has 0 followers
# User ArvindK14011980 has 0 followers
# User bbpatra5346 has 0 followers
# User AmreshK06469067 has 0 followers
# User Mishra1Sarita has 0 followers
# User RishAvT46243903 has 0 followers
# User AmitRai10107084 has 0 followers
# User DRAMANJ87407276 has 0 followers
# User HomSing11058419 has 0 followers
# User AmandaJ95649130 has 0 followers
# User darshiina has 0 followers
# User Mohdhus15327859 has 0 followers

# %% [markdown]
# #### Query 9
#
# ##### Get the number of tweets & retweets per hour
#
# This Neo4j query is composed of several parts that are combined using the `WITH` keyword. The query is used to retrieve data on the number of original tweets and retweets made by users during different hours of the day.
#
# The first part of the query uses the `OPTIONAL MATCH` keyword to match users who have tweeted an original tweet with the `TWEETED_ORIGINAL` relationship, and then calculates the hour of the day using the datetime() function on the tweet's creation date. It then returns the hour, the number of tweets made during that hour, and 0 for the number of retweets. The results are then grouped by the hour and ordered in ascending order.
#
# The second part of the query is similar to the first, but matches users who have retweeted a tweet with the `RETWEETED` relationship instead. It also calculates the hour of the day and returns the hour, 0 for the number of tweets, and the number of retweets made during that hour. The results are also grouped by the hour and ordered in ascending order.
#
# The two parts of the query are combined using the `UNION ALL` keyword to create a single table of results that includes both the original tweets and the retweets. The results are then grouped again by the hour, and the number of tweets and retweets are summed up for each hour.
#
# Finally, the last part of the query selects the hour, the number of tweets, and the number of retweets for each hour, and orders the results in ascending order by hour.
#
# Overall, this query is useful for analyzing Twitter data and understanding how users interact with content on the platform during different hours of the day. The results can be used to identify patterns and trends in user behavior, which can be used to inform social media marketing strategies and content creation efforts.

# %%
query = """
    CALL {
    OPTIONAL MATCH (u:User)-[:TWEETED_ORIGINAL]->(t:Tweet)
    WITH datetime(t.created_at).hour as hour, count(*) as tweets, 0 as retweets
    RETURN hour, sum(tweets) as tweets, sum(retweets) as retweets
    ORDER BY hour ASC

    UNION ALL

    OPTIONAL MATCH (u:User)-[:RETWEETED]->(t:Tweet)
    WITH datetime(t.created_at).hour as hour, 0 as tweets, count(*) as retweets
    RETURN hour, sum(tweets) as tweets, sum(retweets) as retweets
    ORDER BY hour ASC
    }
    WITH hour, sum(tweets) as tweets, sum(retweets) as retweets
    RETURN hour, tweets, retweets
    ORDER BY hour ASC
"""

# Hours in UTC time zone
output = session.run(query)
pd.DataFrame(output.data())
# Out:
#     hour  tweets  retweets
# 0      0     282       743
# 1      1     237       673
# 2      2     225       588
# 3      3     305       732
# 4      4     281       708
# 5      5     341       729
# 6      6     363       838
# 7      7     344       807
# 8      8     419       924
# 9      9     354       943
# 10    10     435      1004
# 11    11     442      1138
# 12    12     534      1137
# 13    13     583      1214
# 14    14     661      1260
# 15    15     706      1371
# 16    16     647      1178
# 17    17     551      1192
# 18    18     507      1127
# 19    19     440      1059
# 20    20     401       916
# 21    21     396       932
# 22    22     273       833
# 23    23     316       841

# %% [markdown]
# #### Query 11
# ##### Get the user with the most replies
#
# Let's analyze another Neo4j query step by step:
#
# 1. `MATCH (u:User)-[:TWEETED_ORIGINAL]->(t:Tweet)` - This line matches all users who have tweeted original tweets and also the tweets they have tweeted.
#
# 2. `WITH u, SUM(t.reply_count) AS total_replies` - This line groups the results by user and calculates the total number of replies on their original tweets.
#
# 3. `RETURN u.userid as UserID, u.username AS Username, total_replies as Total_Replies` - This line returns the user id, username, and the total number of replies for each user.
#
# 4. `ORDER BY total_replies DESC` - This line sorts the result in descending order by the total number of replies.
#
# 5. `LIMIT 1` - This line limits the number of results to just one, which means only the user with the highest number of total replies will be returned.
#
# Therefore, this query returns the user with the highest number of total replies on their original tweets along with their user id and username.
#
# Overall, this query is useful for identifying the most active users who receive a high number of replies on their tweets, which can be helpful for social media marketing and analysis purposes.

# %%
query = """
    MATCH (u:User)-[:TWEETED_ORIGINAL|RETWEETED|REPLIED|QUOTED]->(t:Tweet)
    WITH u, SUM(t.reply_count) AS total_replies
    RETURN u.userid as UserID, u.username AS Username, total_replies as Total_Replies
    ORDER BY total_replies DESC
    LIMIT 1
"""

result = session.run(query)
pd.DataFrame(result.data())
# Out:
#        UserID    Username  Total_Replies
# 0  3939574932  FightHaven          44611

# %% [markdown]
# #### Query 13
# ##### Get the top-20 hashtags that co-occur with the hashtag that has been used the most
#
# We will design a query to find the most popular co-occurring hashtags with the most popular hashtag. Here is a step-by-step analysis of the query:
#
# 1. `MATCH (t:Tweet)-[:HAS_HASHTAG]->(h:Hashtag)` - Matches all tweets that have at least one hashtag and the hashtag nodes they are connected to.
# 2. `WITH h.hashtag AS main_hashtag, collect(DISTINCT t.tweet_id) AS main_tweet_ids` - Groups the tweets by their hashtags, collects the tweet IDs for each hashtag, and assigns the most popular hashtag to main_hashtag.
# 3. `ORDER BY size(main_tweet_ids) DESC LIMIT 1` - Orders the hashtags by the number of tweets that they are in, in descending order, and returns the most popular hashtag.
# 4. `MATCH (t:Tweet)-[:HAS_HASHTAG]->(h:Hashtag)` - Matches all tweets and hashtags again.
# 5. `WHERE h.hashtag <> main_hashtag AND t.tweet_id IN main_tweet_ids` - Filters out the tweets that contain the main hashtag and keeps only those tweets that have at least one hashtag in common with the main hashtag.
# 6. `WITH h.hashtag AS co_hashtag, count(DISTINCT t.tweet_id)` AS co_occurrences, main_hashtag - Groups the tweets by the co-occurring hashtags and counts the number of tweets in which they appear with the main hashtag. Also, assigns the main hashtag to a variable.
# 7. `ORDER BY co_occurrences DESC LIMIT 20` - Orders the co-occurring hashtags by the number of occurrences in descending order and returns only the top 20.
# 8. `RETURN main_hashtag, co_hashtag, co_occurrences` - Returns the main hashtag, the co-occurring hashtags, and their counts.

# %%
result = session.run("""
    MATCH (t:Tweet)-[:HAS_HASHTAG]->(h:Hashtag)
    WITH h.hashtag AS main_hashtag, collect(DISTINCT t.tweet_id) AS main_tweet_ids
    ORDER BY size(main_tweet_ids) DESC LIMIT 1
    MATCH (t:Tweet)-[:HAS_HASHTAG]->(h:Hashtag)
    WHERE h.hashtag <> main_hashtag AND t.tweet_id IN main_tweet_ids
    WITH h.hashtag AS co_hashtag, count(DISTINCT t.tweet_id) AS co_occurrences, main_hashtag
    ORDER BY co_occurrences DESC LIMIT 20
    RETURN main_hashtag, co_hashtag, co_occurrences
    """)

pd.DataFrame(result.data())
# Out:
#    main_hashtag        co_hashtag  co_occurrences
# 0   womenintech            coding             612
# 1   womenintech        javascript             602
# 2   womenintech              tech             574
# 3   womenintech       programming             529
# 4   womenintech      womenwhocode             495
# 5   womenintech     100DaysOfCode             460
# 6   womenintech      DEVCommunity             437
# 7   womenintech     100daysofcode             431
# 8   womenintech        technology             426
# 9   womenintech            python             421
# 10  womenintech                AI             420
# 11  womenintech           100devs             406
# 12  womenintech  blacktechtwitter             381
# 13  womenintech        codenewbie             380
# 14  womenintech            Python             339
# 15  womenintech      WomenWhoCode             308
# 16  womenintech       DataScience             290
# 17  womenintech   MachineLearning             272
# 18  womenintech       techiewomen             248
# 19  womenintech               IoT             243

# %% [markdown]
# #### Query 15
# ##### Get the most "important" user in the dataset (use Graph algorithms: Pagerank, Betweenness centrality, etc). You will apply these algorithms in the mention network (which includes retweets).

# %%
# Query 15 - Most important User
drop_query = """CALL gds.graph.drop('pageRankGraph') YIELD graphName;"""
session.run(drop_query)

create_graph_query = """
CALL gds.graph.project(
  'pageRankGraph',
  'User',
  {
    MENTIONED: {
      type: 'MENTIONED',
      orientation: 'NATURAL'
    }
  }
)
"""

pagerank_query = """
CALL gds.pageRank.stream('pageRankGraph')
YIELD nodeId, score
WITH nodeId, score
ORDER BY score DESC
MATCH (u:User)
WHERE id(u) = nodeId
WITH u.username AS username, MAX(score) AS max_score
RETURN DISTINCT username, max_score
"""

session.run(create_graph_query)
result = session.run(pagerank_query)
display(pd.DataFrame(result.data()))
# Out:
#               username   max_score
# 0      cryptosanthoshK  189.487500
# 1       Khulood_Almani  122.873344
# 2         GirlsWhoCode  122.225949
# 3      CatherineAdenle  111.718941
# 4          drlaxmanbjp  106.087470
# ...                ...         ...
# 18058       mandanaIR_    0.150000
# 18059  jijothelappilly    0.150000
# 18060       Damibanjo2    0.150000
# 18061       micanyonge    0.150000
# 18062       Realmadtkh    0.150000
#
# [18063 rows x 2 columns]

# %% [markdown]
# #### Query 17
# ##### For the 5th most important user, get the list of hashtags and URLs that have been posted (if no hashtags or URLs - check another user e.g. 6th, 7th , etc..)

# %%
query = """
MATCH (u1:User)-[:USED_HASHTAG]->(u1_hashtag:Hashtag)
WHERE u1.username = "CatherineAdenle"
RETURN DISTINCT u1_hashtag.hashtag AS output

UNION ALL

MATCH (u1:User)-[:USED_URL]->(u1_url:URL)
WHERE u1.username = "CatherineAdenle"
RETURN DISTINCT u1_url.url AS output
"""

result = session.run(query)
print(np.array(result.values()).ravel())
# Out:
# ['DataScience' 'NLP' 'Cloud' 'CyberSecurity' 'womenintech' 'TensorFlow'
#  'IoT' 'Fintech' 'flutter' '100DaysOfCode' 'coding' 'MachineLearning' 'AI'
#  'Programming' 'javascript' 'Python' 'Analytics' 'Business' 'Bigdata'
#  'Data' 'TechNews' 'technology' '100DaysOfMLCode' 'DEVCommunity'
#  'programming' 'ML' 'ethics' 'artificalintelligence' 'Microsoft'
#  'innovation' 'techtwitter' 'tech' 'PredictiveProgramming'
#  'ArtificialIntelligence' 'ChatGPTGOD' 'ChatGPT' 'BigData' 'fintech'
#  'CloudComputing' 'machinelearning' 'productengineering' 'UI' 'UX'
#  'productdesign' '5G' 'CES' 'BlackTechTwitter' 'mobile' 'Gadget'
#  'prototype' 'phone' 'Samsung' 'CES2023' 'MWC2023' 'Electronic' 'gadget'
#  'VR' 'wearables' 'autonomous' 'chatgpt' 'metaverse' '100daysofcode'
#  'devcommunity' 'Coding' 'java' 'IIoT' 'Tech' 'Rstats' 'DataScientists'
#  'DeepLearning' 'jobs' 'CodeT5' 'JavaScript' 'codenewbies' 'Womenintech'
#  'openAI' '100daysofCoding' 'coders' 'GitHub' 'automation'
#  'artificialIntelligence' 'datasets' 'CheatSheet' 'CodeNewbies' 'DL'
#  'https://twitter.com/CatherineAdenle/status/1609138389114028032/photo/1'
#  'https://bit.ly/3Gux92i'
#  'https://twitter.com/CatherineAdenle/status/1609135809420054529/photo/1'
#  'https://twitter.com/CatherineAdenle/status/1609490743248158720/photo/1'
#  'https://twitter.com/CatherineAdenle/status/1609497735207477251/photo/1'
#  'https://blog.dataiku.com/the-different-types-of-data-scientists-and-what-kind-you-should-hire'
#  'https://twitter.com/CatherineAdenle/status/1610367014173904897/photo/1'
#  'https://bit.ly/3cnYOpr'
#  'https://twitter.com/CatherineAdenle/status/1563140960439046151/photo/1'
#  'https://bit.ly/3VOsf4C'
#  'https://careerfoundry.com/en/blog/data-analytics/data-scientist-salary/'
#  'https://twitter.com/CatherineAdenle/status/1610591948573753344/photo/1'
#  'https://catherinescareercorner.com/2021/04/17/the-5-ultimate-skills-of-a-seasoned-data-scientist/'
#  'https://www.wired.com/story/ces-2023-what-to-expect/'
#  'https://twitter.com/LaurentAlaus/status/1611062324328075269/video/1'
#  'https://twitter.com/CurieuxExplorer/status/1610547866195615749/video/1'
#  'https://twitter.com/CatherineAdenle/status/1608795408012300288/photo/1'
#  'https://www.analyticsinsight.net/top-10-companies-offering-ai-solutions-via-the-cloud-to-boost-profits/'
#  'https://cnb.cx/3GybMMa' 'https://www.adalovelaceinstitute.org/?p=19871'
#  'https://twitter.com/CatherineAdenle/status/1614179302320267264/photo/1']

# %% [markdown]
# #### Query 19
# ##### Get the user communities that have been created based on the users' interactions and visualize them (Louvain algorithm).

# %%
# drop_query = """CALL gds.graph.drop('louvainGraph') YIELD graphName;"""
# session.run(drop_query)

create_graph_query = """
CALL gds.graph.project(
  'louvainGraph',
  ['User'],
  ['MENTIONED', 'TWEETED_ORIGINAL', 'USED_HASHTAG', 'USED_URL']
)
"""

louvain_query = """
CALL gds.louvain.write('louvainGraph', {writeProperty: 'community'})
YIELD communityCount, modularity, modularities
"""
session.run(create_graph_query)
result = session.run(louvain_query)
communities = pd.DataFrame(result.data())
communities
# Out:
#    communityCount  modularity  \
# 0            4007    0.782913
#
#                                         modularities
# 0  [0.7245289915561008, 0.7684591768066569, 0.776...

# %% [markdown]
# #### Extra Query 1
# ##### Get the top-10 users who posted the most tweets during the year 2022. In order to count a tweet, it should contain at least one of the top-5 mostly used hashtags of all time.

# %%
query = """
    MATCH (u:User)-[:TWEETED_ORIGINAL]->(t:Tweet)-[:HAS_HASHTAG]->(h:Hashtag)
    WITH h, count(DISTINCT h) AS hashtag_count
    ORDER BY hashtag_count DESC
    LIMIT 5
    WITH collect(h) AS top_hashtags
    MATCH (u:User)-[:TWEETED_ORIGINAL]->(t:Tweet)-[:HAS_HASHTAG]->(h:Hashtag)
    WHERE h IN top_hashtags AND datetime(t.created_at) >= datetime('2022-01-01T00:00:00.000Z') AND datetime(t.created_at) < datetime('2023-01-01T00:00:00.000Z')
    WITH u, count(DISTINCT t) AS tweet_count
    ORDER BY tweet_count DESC
    LIMIT 10
    RETURN u.username, tweet_count
"""

result = session.run(query)
pd.DataFrame(result.data())
# Out:
#         u.username  tweet_count
# 0   Khulood_Almani           65
# 1     WomenTechNet           37
# 2      Eli_Krumova           20
# 3           alod83           13
# 4  CatherineAdenle            5
# 5     WomenWhoCode            5
# 6  Manish_kumar3_1            3
# 7     Strategy_Gal            3
# 8     hertechtrail            3
# 9  WestArt_Factory            3

# %% [markdown]
# #### Extra Query 2
# ##### Get the users which have minimum average tweets per day bigger than the average number of tweets of a user per day. Only users with more that 2 tweets per day will be used in order to calculate the average number of tweets per day.

# %%
query = """
MATCH (u:User)-[:TWEETED_ORIGINAL]->(t:Tweet) 
WITH u, count(t) as numTweets, date(datetime(t.created_at)) as tweetDate
WITH u, numTweets, min(tweetDate) as minTweetDate, max(tweetDate) as maxTweetDate
WITH u, numTweets, duration.between(minTweetDate, maxTweetDate).days + 1 as numDays
WITH u, numTweets / toFloat(numDays) as tweetsPerDay
WITH u, min(tweetsPerDay) as minTweetsPerDay
CALL {
    MATCH (u:User)-[:TWEETED_ORIGINAL]->(t:Tweet)
    WITH u, count(t) as numTweets, date(datetime(t.created_at)) as tweetDate
    WITH u, numTweets, min(tweetDate) as minTweetDate, max(tweetDate) as maxTweetDate
    WITH u, numTweets, duration.between(minTweetDate, maxTweetDate).days + 1 as numDays
    WITH u, numTweets / toFloat(numDays) as tweetsPerDay
    WHERE numTweets > 1
    WITH avg(tweetsPerDay) as totalAvgTweetsPerDay
    RETURN totalAvgTweetsPerDay
}
with minTweetsPerDay, totalAvgTweetsPerDay, u.username as username
WHERE minTweetsPerDay > totalAvgTweetsPerDay
RETURN username, minTweetsPerDay
ORDER BY minTweetsPerDay DESC
"""

result = session.run(query)
pd.DataFrame(result.data())
# Out:
#           username  minTweetsPerDay
# 0     VivianAaron5             71.0
# 1          mrflean              5.0
# 2         ColorsTV              5.0
# 3      fabinsanity              4.0
# 4    Help4uHealthy              4.0
# 5  Freelancerkelvn              4.0
# 6  HackwithNichola              4.0
